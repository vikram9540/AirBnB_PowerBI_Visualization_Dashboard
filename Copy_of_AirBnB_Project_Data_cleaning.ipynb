# %% [markdown]
# <a href="https://colab.research.google.com/github/vikram9540/AirBnB_PowerBI_Visualization_Dashboard/blob/main/Copy_of_AirBnB_Project_Data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
listNO=pd.read_csv('/content/drive/MyDrive/Project/Power BI/AirBnb Project/listings NO (1).csv')
listCH=pd.read_csv('/content/drive/MyDrive/Project/Power BI/AirBnb Project/listings CH (1).csv')

# %%
listCH.head()
# Out:
#       id                                        name  host_id  \
# 0   2384   Hyde Park - Walk to University of Chicago     2613
# 1   7126         Tiny Studio Apartment 94 Walk Score    17928
# 2  10945                       The Biddle House (#1)    33004
# 3  28749  Quirky Bucktown Loft w/ Parking No Parties    27506
# 4  71930                     Rest, Relax and Explore   334241
#
#               host_name  neighbourhood_group neighbourhood  latitude  \
# 0               Rebecca                  NaN     Hyde Park  41.78790
# 1                 Sarah                  NaN     West Town  41.90166
# 2           At Home Inn                  NaN  Lincoln Park  41.91196
# 3                 Lauri                  NaN  Logan Square  41.91955
# 4  Michael And Veronica                  NaN     West Town  41.89615
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0  -87.58780     Private room  125.0               3                250
# ...

# %%
listNO.head()
# Out:
#       id                                name  host_id host_name  \
# 0  19091      Fully Furnished Cozy Apartment    72880      John
# 1  71624  Ravenwood Manor (Historic Bywater)   367223     Susan
# 2  74498                     Maison Marais 1   391462   Georgia
# 3  79536   FeelAtHomeInNewOrleans-PrivateApt   428362    Miriam
# 4  79609         Bywater's Original & Finest   428909   Stephen
#
#    neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0                  NaN      Leonidas  29.96100  -90.11950  Entire home/apt
# 1                  NaN       Bywater  29.96153  -90.04364  Entire home/apt
# 2                  NaN      St. Roch  29.96986  -90.05172  Entire home/apt
# 3                  NaN  Seventh Ward  29.97803  -90.07450  Entire home/apt
# 4                  NaN    St. Claude  29.96448  -90.03667  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# ...

# %%
listCH.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8748 entries, 0 to 8747
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              8748 non-null   int64
#  1   name                            8748 non-null   object
#  2   host_id                         8748 non-null   int64
#  3   host_name                       8748 non-null   object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   8748 non-null   object
#  6   latitude                        8748 non-null   float64
#  7   longitude                       8748 non-null   float64
#  8   room_type                       8748 non-null   object
#  9   price                           7718 non-null   float64
#  10  minimum_nights                  8748 non-null   int64
#  11  number_of_reviews               8748 non-null   int64
# ...

# %%
listNO.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7842 entries, 0 to 7841
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              7842 non-null   int64
#  1   name                            7842 non-null   object
#  2   host_id                         7842 non-null   int64
#  3   host_name                       7829 non-null   object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   7842 non-null   object
#  6   latitude                        7842 non-null   float64
#  7   longitude                       7842 non-null   float64
#  8   room_type                       7842 non-null   object
#  9   price                           6640 non-null   float64
#  10  minimum_nights                  7842 non-null   int64
#  11  number_of_reviews               7842 non-null   int64
# ...

# %%
listCH.drop('neighbourhood_group', axis=1, inplace=True)

# %%
listNO.drop('neighbourhood_group', axis=1, inplace=True)

# %%
listCH.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8748 entries, 0 to 8747
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              8748 non-null   int64
#  1   name                            8748 non-null   object
#  2   host_id                         8748 non-null   int64
#  3   host_name                       8748 non-null   object
#  4   neighbourhood                   8748 non-null   object
#  5   latitude                        8748 non-null   float64
#  6   longitude                       8748 non-null   float64
#  7   room_type                       8748 non-null   object
#  8   price                           7718 non-null   float64
#  9   minimum_nights                  8748 non-null   int64
#  10  number_of_reviews               8748 non-null   int64
#  11  last_review                     6870 non-null   object
# ...

# %%
listNO.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7842 entries, 0 to 7841
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              7842 non-null   int64
#  1   name                            7842 non-null   object
#  2   host_id                         7842 non-null   int64
#  3   host_name                       7829 non-null   object
#  4   neighbourhood                   7842 non-null   object
#  5   latitude                        7842 non-null   float64
#  6   longitude                       7842 non-null   float64
#  7   room_type                       7842 non-null   object
#  8   price                           6640 non-null   float64
#  9   minimum_nights                  7842 non-null   int64
#  10  number_of_reviews               7842 non-null   int64
#  11  last_review                     6514 non-null   object
# ...

# %%
listNO.isnull().sum()
# Out:
# id                                   0
# name                                 0
# host_id                              0
# host_name                           13
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                             1202
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       1328
# reviews_per_month                 1328
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# license                           1349
# dtype: int64

# %%
listCH.isnull().sum()
# Out:
# id                                   0
# name                                 0
# host_id                              0
# host_name                            0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                             1030
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       1878
# reviews_per_month                 1878
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# license                           1903
# dtype: int64

# %%
# changing the datatype of date column
listCH['last_review'] = pd.to_datetime(listCH['last_review'])
listNO['last_review'] = pd.to_datetime(listNO['last_review'])

# %%
listCH.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8748 entries, 0 to 8747
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              8748 non-null   int64
#  1   name                            8748 non-null   object
#  2   host_id                         8748 non-null   int64
#  3   host_name                       8748 non-null   object
#  4   neighbourhood                   8748 non-null   object
#  5   latitude                        8748 non-null   float64
#  6   longitude                       8748 non-null   float64
#  7   room_type                       8748 non-null   object
#  8   price                           7718 non-null   float64
#  9   minimum_nights                  8748 non-null   int64
#  10  number_of_reviews               8748 non-null   int64
#  11  last_review                     6870 non-null   datetime64[ns]
# ...

# %%
listNO.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7842 entries, 0 to 7841
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              7842 non-null   int64
#  1   name                            7842 non-null   object
#  2   host_id                         7842 non-null   int64
#  3   host_name                       7829 non-null   object
#  4   neighbourhood                   7842 non-null   object
#  5   latitude                        7842 non-null   float64
#  6   longitude                       7842 non-null   float64
#  7   room_type                       7842 non-null   object
#  8   price                           6640 non-null   float64
#  9   minimum_nights                  7842 non-null   int64
#  10  number_of_reviews               7842 non-null   int64
#  11  last_review                     6514 non-null   datetime64[ns]
# ...

# %%
#filling na in price columns
listCH['price'].fillna(listCH['price'].mode()[0], inplace=True)
listNO['price'].fillna(listNO['price'].mode()[0], inplace=True)
# Out:
# <ipython-input-47-f172eedb9dfb>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   listCH['price'].fillna(listCH['price'].mode()[0], inplace=True)
# <ipython-input-47-f172eedb9dfb>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
listCH.isnull().sum()
# Out:
# id                                   0
# name                                 0
# host_id                              0
# host_name                            0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       1878
# reviews_per_month                 1878
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# license                           1903
# dtype: int64

# %%
listNO.isnull().sum()
# Out:
# id                                   0
# name                                 0
# host_id                              0
# host_name                           13
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       1328
# reviews_per_month                 1328
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# license                           1349
# dtype: int64

# %%
listCH.to_excel('/content/drive/MyDrive/Project/Power BI/AirBnb Project/listings CH (1).csv', index=False)

# %%
listNO.to_excel('/content/drive/MyDrive/Project/Power BI/AirBnb Project/listings NO (1).csv', index=False )
